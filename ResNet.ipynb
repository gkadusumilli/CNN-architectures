# %% [markdown]
# #<center>CNN Architectures </center>
#
#
# #<center> Part 5: ResNet implementation using keras<center>
#
# In this notebook we will build ResNet model from the scratch using keras.
#
# Link to the ResNet Paper: https://arxiv.org/abs/1512.03385
#
# **ResNet was developed by a group from the Microsoft Research team in the year 2015.**
#
# ResNet have developed deep neural networks with 50, 101, and 152 weight layers with less complexity.
#
# The key highlight in ResNet is the residual module architecture with the skip connections.

# %% [markdown]
# ResNet architecture
#
# 1. Skip connections: To solve the vanishing gradient problem in the deeper networks
#
# 2. Zero pooling layers in the residual block, Instead used bottleneck residual block of 1 x 1 Conv layers.
#
#
# What is **"Vanishing gradient problem"**
#
# As the network backpropagates the gradient of the error from the final layer back to the first layer, it is multipl'ied by the weight matrix at each step; thus the gradient can decrease exponetially quickly to zero. leading to a vanishing gradient phenomenon that prevents earlier layers from learning. As a result, the networks performance gets saturated or even starts to degrade rapidly.
#
# To address this authors have introduced "skip connections"

# %% [markdown]
# ####Residual blocks
#
# A residual module consists of two branches
#
# 1. **Shortcut path** - Connects the input to an addition of the second branch
#
# 2. **Main path**: a series of convolutions and activation. The main path consists of three convolutional layers with ReLu activations. we also add batch normalization to each convolutional layer to reduce overfitting and speed up training.
#
# > The main path architecture is as below
#
# > [CONV --> BN --> ReLU] x 3
#
# > Note: Shortcut arrow points to the end of the second convolutional layer right before the ReLu activation function.
#
# > There are no pooling layers in the residual block, rather authors have decided to do ***dimension downsampling using bottlenect 1 x 1 convolutional layers*** to dowsample the output, this configuration is called a bottleneck residual block.
#
#
# Types of shortcut path
#
# 1. Regular shortcut - Adds the input dimensions to the main path
#
# ![residual](https://raw.githubusercontent.com/gkadusumilli/CNN-architectures/main/Residual_blocks.png)
#
# 2. Reduce shortcut - Adds a convolutional layer in the shortcut path before merging the main path
#
# ![residual_shortcut_reduce](https://raw.githubusercontent.com/gkadusumilli/CNN-architectures/main/Residual_blocks_reduced_shortcut%20(1).png
# )

# %% [markdown]
# ####Summary of the residual blocks
#
# * Residual blocks contain two paths: The shortcut path and the main path.
#
# * The main path consists of three convolutional layers and we add batch normalization layer to them:
#
# >> 1 x 1 convolutional layer
# >> 3 x 3 convolutional layer
# >> 1 x 1 convolutional layer
#
# * Two ways to implement the shortcut path
# >> Regular shortcut
# >> Reduce shortcut

# %% [markdown]
# ####ResNet50 network
#
# Stage 1: 7 x 7 convolutional layer
#
# Stage 2: 3 residual blocks, each containing [1 x 1 conv layer + 3 x 3 conv layer + 1 x 1 conv layer] = 9 conv layers
#
# Stage 3: 4 residual blocks = total 12 conv layers
#
# Stage 4: 6 residual blocks = total of 18 conv layers
#
# Stage 5: 3 residual blocks =  total of 9 conv layers
#
# Fully connected softmax layer.

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
#training parameters
batch_size = 32
epochs = 200
data_augmentation = True
num_classes = 10

#substracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
n = 6
depth = n * 9 + 2

#load the CIFAR 10 data
(x_train, y_train),(x_test,y_test) = cifar10.load_data()

#input image dimensions
input_shape = x_train.shape[1:]
#normalize the data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

if subtract_pixel_mean:
  x_train_mean = np.mean(x_train, axis=0)
  x_train -=x_train_mean
  x_test -=x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

#convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

def lr_schedule(epoch):
  """Learning Rate Schedule
  Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs

  Called automatically every epoch as part of callbacks during training"""

  lr = 1e-3
  if epoch > 180:
    lr *=0.5e-3
  elif epoch > 160:
    lr *=1e-3
  elif epoch > 120:
    lr *=1e-2
  elif epoch>80:
    lr *=1e-1
  print('Learning rate: ',lr)
  return lr
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model



model = resnet_v2(input_shape=input_shape, depth=depth)


model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 16)   448         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 16)   64          conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 16)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 32, 16)   272         activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 16)   64          conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 32, 32, 16)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 32, 16)   2320        activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 16)   64          conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 32, 16)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 32, 64)   1088        activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 32, 64)   1088        activation_67[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 64)   0           conv2d_78[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 64)   256         add_20[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 64)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 32, 32, 16)   1040        activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 16)   64          conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 16)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 32, 32, 16)   2320        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 32, 32, 16)   64          conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 16)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 32, 32, 64)   1088        activation_70[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 64)   0           add_20[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 64)   256         add_21[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 32, 32, 64)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 32, 32, 16)   1040        activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 32, 32, 16)   64          conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 32, 32, 16)   0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 32, 16)   2320        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 32, 32, 16)   64          conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 32, 32, 16)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 32, 64)   1088        activation_73[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 32, 32, 64)   0           add_21[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 32, 32, 64)   256         add_22[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 32, 32, 64)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 16)   1040        activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 32, 32, 16)   64          conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 32, 32, 16)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 32, 32, 16)   2320        activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 32, 32, 16)   64          conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 32, 32, 16)   0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 32, 32, 64)   1088        activation_76[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 32, 32, 64)   0           add_22[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 32, 32, 64)   256         add_23[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 32, 32, 64)   0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 32, 32, 16)   1040        activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 32, 32, 16)   64          conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 32, 32, 16)   0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 32, 32, 16)   2320        activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 32, 32, 16)   64          conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 32, 32, 16)   0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 32, 32, 64)   1088        activation_79[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 32, 32, 64)   0           add_23[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 32, 32, 64)   256         add_24[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 32, 32, 64)   0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 32, 32, 16)   1040        activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 32, 32, 16)   64          conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 32, 32, 16)   0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 32, 32, 16)   2320        activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 32, 32, 16)   64          conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 32, 32, 16)   0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 32, 64)   1088        activation_82[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 32, 32, 64)   0           add_24[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 32, 32, 64)   256         add_25[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 32, 32, 64)   0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 16, 16, 64)   4160        activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 16, 16, 64)   256         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 16, 16, 64)   0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 16, 16, 64)   36928       activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 16, 16, 64)   256         conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 16, 16, 64)   0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 16, 16, 128)  8320        add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 16, 16, 128)  8320        activation_85[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 16, 16, 128)  0           conv2d_97[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 16, 16, 128)  512         add_26[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 16, 16, 128)  0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 16, 16, 64)   8256        activation_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 16, 16, 64)   256         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 16, 16, 64)   0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 16, 16, 64)   36928       activation_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 16, 16, 64)   256         conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 16, 16, 64)   0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 16, 16, 128)  8320        activation_88[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 16, 16, 128)  0           add_26[0][0]
#                                                                  conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 16, 16, 128)  512         add_27[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 16, 16, 128)  0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 16, 16, 64)   8256        activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 16, 16, 64)   256         conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 16, 16, 64)   0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 16, 16, 64)   36928       activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 16, 16, 64)   256         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 16, 16, 64)   0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 16, 16, 128)  8320        activation_91[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 16, 16, 128)  0           add_27[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 16, 16, 128)  512         add_28[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 16, 16, 128)  0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 16, 16, 64)   8256        activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 16, 16, 64)   256         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 16, 16, 64)   0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 16, 16, 64)   36928       activation_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 16, 16, 64)   256         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 16, 16, 64)   0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 16, 16, 128)  8320        activation_94[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 16, 16, 128)  0           add_28[0][0]
#                                                                  conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 16, 16, 128)  512         add_29[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 16, 16, 128)  0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 16, 16, 64)   8256        activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 16, 16, 64)   256         conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 16, 16, 64)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 16, 16, 64)   36928       activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 16, 16, 64)   256         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 16, 16, 64)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 16, 16, 128)  8320        activation_97[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 16, 16, 128)  0           add_29[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 16, 16, 128)  512         add_30[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 16, 16, 128)  0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 16, 16, 64)   8256        activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 16, 16, 64)   256         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 16, 16, 64)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 16, 16, 64)   36928       activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 16, 16, 64)   256         conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 16, 16, 64)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 16, 16, 128)  8320        activation_100[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 16, 16, 128)  0           add_30[0][0]
#                                                                  conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 16, 16, 128)  512         add_31[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 16, 16, 128)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 8, 8, 128)    16512       activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 8, 8, 128)    512         conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 8, 8, 128)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 8, 8, 128)    147584      activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 8, 8, 128)    512         conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 8, 8, 128)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 8, 8, 256)    33024       add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 8, 8, 256)    33024       activation_103[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 8, 8, 256)    0           conv2d_116[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 8, 8, 256)    1024        add_32[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 8, 8, 256)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 8, 8, 128)    32896       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 8, 8, 128)    512         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 8, 8, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 8, 8, 128)    147584      activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 8, 8, 128)    512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 8, 8, 128)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 8, 8, 256)    33024       activation_106[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 8, 8, 256)    0           add_32[0][0]
#                                                                  conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 8, 8, 256)    1024        add_33[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 8, 8, 256)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 8, 8, 128)    32896       activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 8, 8, 128)    512         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 8, 8, 128)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 8, 8, 128)    147584      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 8, 8, 128)    512         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 8, 8, 128)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 256)    33024       activation_109[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 8, 8, 256)    0           add_33[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 8, 8, 256)    1024        add_34[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 8, 8, 256)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 8, 8, 128)    32896       activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 8, 8, 128)    512         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 8, 8, 128)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 8, 8, 128)    147584      activation_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 8, 8, 128)    512         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 8, 8, 128)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 256)    33024       activation_112[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 256)    0           add_34[0][0]
#                                                                  conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 8, 8, 256)    1024        add_35[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 8, 8, 256)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 128)    32896       activation_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 8, 8, 128)    512         conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 8, 8, 128)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 8, 128)    147584      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 8, 8, 128)    512         conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 8, 8, 128)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 8, 256)    33024       activation_115[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 8, 8, 256)    0           add_35[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 8, 8, 256)    1024        add_36[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 8, 8, 256)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 128)    32896       activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 8, 8, 128)    512         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 8, 8, 128)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 128)    147584      activation_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 8, 8, 128)    512         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 8, 8, 128)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 8, 256)    33024       activation_118[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 8, 8, 256)    0           add_36[0][0]
#                                                                  conv2d_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 8, 8, 256)    1024        add_37[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 8, 8, 256)    0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           activation_119[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        flatten_1[0][0]
# ==================================================================================================
# Total params: 1,673,738
# Trainable params: 1,663,338
# Non-trainable params: 10,400
# __________________________________________________________________________________________________

# %%
#prepare model saving directory

save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name='cifar10_%s_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)
filepath=os.path.join(save_dir, model_name)

# %%
#prepare callbacks for model saving and for learning rate adjustment

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler=LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
datagen=ImageDataGenerator(
    rotation_range=0,
    width_shift_range=0.1,
    shear_range=0.,
    zoom_range=0.,
    fill_mode='nearest',
    horizontal_flip=True
)
datagen.fit(x_train)

# %%
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    validation_data=(x_test,y_test),
                    epochs=epochs, verbose=1, workers=4,
                    steps_per_epoch=x_train.shape[0] //batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/200
# Learning rate:  0.001
#    1/1562 [..............................] - ETA: 3:08 - loss: 1.2022 - accuracy: 0.7188
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 1562/1562 [==============================] - 62s 39ms/step - loss: 1.3524 - accuracy: 0.6638 - val_loss: 1.2559 - val_accuracy: 0.6802
#
# Epoch 00001: val_accuracy improved from -inf to 0.68020, saving model to /content/saved_models/cifar10_%s_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 1.1535 - accuracy: 0.7160 - val_loss: 1.2173 - val_accuracy: 0.6951
#
# Epoch 00002: val_accuracy improved from 0.68020 to 0.69510, saving model to /content/saved_models/cifar10_%s_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 1.0424 - accuracy: 0.7488 - val_loss: 1.3419 - val_accuracy: 0.6686
#
# Epoch 00003: val_accuracy did not improve from 0.69510
# Epoch 4/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.9717 - accuracy: 0.7700 - val_loss: 1.2337 - val_accuracy: 0.6894
#
# Epoch 00004: val_accuracy did not improve from 0.69510
# Epoch 5/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.9122 - accuracy: 0.7861 - val_loss: 0.8777 - val_accuracy: 0.7985
#
# Epoch 00005: val_accuracy improved from 0.69510 to 0.79850, saving model to /content/saved_models/cifar10_%s_model.005.h5
# Epoch 6/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.8660 - accuracy: 0.8013 - val_loss: 1.0430 - val_accuracy: 0.7509
#
# Epoch 00006: val_accuracy did not improve from 0.79850
# Epoch 7/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.8313 - accuracy: 0.8081 - val_loss: 0.9976 - val_accuracy: 0.7608
#
# Epoch 00007: val_accuracy did not improve from 0.79850
# Epoch 8/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.8018 - accuracy: 0.8176 - val_loss: 0.9526 - val_accuracy: 0.7782
#
# Epoch 00008: val_accuracy did not improve from 0.79850
# Epoch 9/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.7735 - accuracy: 0.8234 - val_loss: 0.9415 - val_accuracy: 0.7831
#
# Epoch 00009: val_accuracy did not improve from 0.79850
# Epoch 10/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.7510 - accuracy: 0.8323 - val_loss: 0.8412 - val_accuracy: 0.8038
#
# Epoch 00010: val_accuracy improved from 0.79850 to 0.80380, saving model to /content/saved_models/cifar10_%s_model.010.h5
# Epoch 11/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.7338 - accuracy: 0.8375 - val_loss: 0.9229 - val_accuracy: 0.7730
#
# Epoch 00011: val_accuracy did not improve from 0.80380
# Epoch 12/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.7129 - accuracy: 0.8424 - val_loss: 0.8353 - val_accuracy: 0.8084
#
# Epoch 00012: val_accuracy improved from 0.80380 to 0.80840, saving model to /content/saved_models/cifar10_%s_model.012.h5
# Epoch 13/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.6973 - accuracy: 0.8471 - val_loss: 0.8142 - val_accuracy: 0.8105
#
# Epoch 00013: val_accuracy improved from 0.80840 to 0.81050, saving model to /content/saved_models/cifar10_%s_model.013.h5
# Epoch 14/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.6814 - accuracy: 0.8520 - val_loss: 0.7925 - val_accuracy: 0.8143
#
# Epoch 00014: val_accuracy improved from 0.81050 to 0.81430, saving model to /content/saved_models/cifar10_%s_model.014.h5
# Epoch 15/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.6716 - accuracy: 0.8536 - val_loss: 0.8862 - val_accuracy: 0.7935
#
# Epoch 00015: val_accuracy did not improve from 0.81430
# Epoch 16/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.6517 - accuracy: 0.8613 - val_loss: 0.7687 - val_accuracy: 0.8219
#
# Epoch 00016: val_accuracy improved from 0.81430 to 0.82190, saving model to /content/saved_models/cifar10_%s_model.016.h5
# Epoch 17/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6454 - accuracy: 0.8624 - val_loss: 0.9011 - val_accuracy: 0.7854
#
# Epoch 00017: val_accuracy did not improve from 0.82190
# Epoch 18/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.6375 - accuracy: 0.8648 - val_loss: 0.9398 - val_accuracy: 0.7807
#
# Epoch 00018: val_accuracy did not improve from 0.82190
# Epoch 19/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6247 - accuracy: 0.8689 - val_loss: 0.7356 - val_accuracy: 0.8297
#
# Epoch 00019: val_accuracy improved from 0.82190 to 0.82970, saving model to /content/saved_models/cifar10_%s_model.019.h5
# Epoch 20/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6145 - accuracy: 0.8723 - val_loss: 0.8612 - val_accuracy: 0.8013
#
# Epoch 00020: val_accuracy did not improve from 0.82970
# Epoch 21/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6112 - accuracy: 0.8715 - val_loss: 0.8182 - val_accuracy: 0.8078
#
# Epoch 00021: val_accuracy did not improve from 0.82970
# Epoch 22/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6017 - accuracy: 0.8741 - val_loss: 0.7006 - val_accuracy: 0.8400
#
# Epoch 00022: val_accuracy improved from 0.82970 to 0.84000, saving model to /content/saved_models/cifar10_%s_model.022.h5
# Epoch 23/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5965 - accuracy: 0.8766 - val_loss: 0.6991 - val_accuracy: 0.8449
#
# Epoch 00023: val_accuracy improved from 0.84000 to 0.84490, saving model to /content/saved_models/cifar10_%s_model.023.h5
# Epoch 24/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5904 - accuracy: 0.8786 - val_loss: 0.7782 - val_accuracy: 0.8259
#
# Epoch 00024: val_accuracy did not improve from 0.84490
# Epoch 25/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5826 - accuracy: 0.8805 - val_loss: 0.8953 - val_accuracy: 0.7901
#
# Epoch 00025: val_accuracy did not improve from 0.84490
# Epoch 26/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5737 - accuracy: 0.8818 - val_loss: 0.8121 - val_accuracy: 0.8146
#
# Epoch 00026: val_accuracy did not improve from 0.84490
# Epoch 27/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5732 - accuracy: 0.8826 - val_loss: 0.6873 - val_accuracy: 0.8461
#
# Epoch 00027: val_accuracy improved from 0.84490 to 0.84610, saving model to /content/saved_models/cifar10_%s_model.027.h5
# Epoch 28/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5662 - accuracy: 0.8843 - val_loss: 0.7060 - val_accuracy: 0.8381
#
# Epoch 00028: val_accuracy did not improve from 0.84610
# Epoch 29/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5617 - accuracy: 0.8853 - val_loss: 0.6883 - val_accuracy: 0.8483
#
# Epoch 00029: val_accuracy improved from 0.84610 to 0.84830, saving model to /content/saved_models/cifar10_%s_model.029.h5
# Epoch 30/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5577 - accuracy: 0.8863 - val_loss: 0.7642 - val_accuracy: 0.8309
#
# Epoch 00030: val_accuracy did not improve from 0.84830
# Epoch 31/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5498 - accuracy: 0.8900 - val_loss: 0.6789 - val_accuracy: 0.8534
#
# Epoch 00031: val_accuracy improved from 0.84830 to 0.85340, saving model to /content/saved_models/cifar10_%s_model.031.h5
# Epoch 32/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5407 - accuracy: 0.8934 - val_loss: 0.7887 - val_accuracy: 0.8232
#
# Epoch 00032: val_accuracy did not improve from 0.85340
# Epoch 33/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5441 - accuracy: 0.8905 - val_loss: 0.8662 - val_accuracy: 0.8033
#
# Epoch 00033: val_accuracy did not improve from 0.85340
# Epoch 34/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5393 - accuracy: 0.8925 - val_loss: 0.8157 - val_accuracy: 0.8131
#
# Epoch 00034: val_accuracy did not improve from 0.85340
# Epoch 35/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5350 - accuracy: 0.8945 - val_loss: 0.7914 - val_accuracy: 0.8231
#
# Epoch 00035: val_accuracy did not improve from 0.85340
# Epoch 36/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5363 - accuracy: 0.8940 - val_loss: 0.6708 - val_accuracy: 0.8600
#
# Epoch 00036: val_accuracy improved from 0.85340 to 0.86000, saving model to /content/saved_models/cifar10_%s_model.036.h5
# Epoch 37/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5285 - accuracy: 0.8965 - val_loss: 0.6545 - val_accuracy: 0.8606
#
# Epoch 00037: val_accuracy improved from 0.86000 to 0.86060, saving model to /content/saved_models/cifar10_%s_model.037.h5
# Epoch 38/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5263 - accuracy: 0.8974 - val_loss: 0.8184 - val_accuracy: 0.8155
#
# Epoch 00038: val_accuracy did not improve from 0.86060
# Epoch 39/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5262 - accuracy: 0.8963 - val_loss: 0.6844 - val_accuracy: 0.8457
#
# Epoch 00039: val_accuracy did not improve from 0.86060
# Epoch 40/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.5203 - accuracy: 0.8970 - val_loss: 0.6899 - val_accuracy: 0.8466
#
# Epoch 00040: val_accuracy did not improve from 0.86060
# Epoch 41/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.5169 - accuracy: 0.8998 - val_loss: 0.8215 - val_accuracy: 0.8155
#
# Epoch 00041: val_accuracy did not improve from 0.86060
# Epoch 42/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5168 - accuracy: 0.9001 - val_loss: 0.7601 - val_accuracy: 0.8380
#
# Epoch 00042: val_accuracy did not improve from 0.86060
# Epoch 43/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 64s 41ms/step - loss: 0.5074 - accuracy: 0.9017 - val_loss: 0.6307 - val_accuracy: 0.8609
#
# Epoch 00043: val_accuracy improved from 0.86060 to 0.86090, saving model to /content/saved_models/cifar10_%s_model.043.h5
# Epoch 44/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5107 - accuracy: 0.9004 - val_loss: 0.6629 - val_accuracy: 0.8549
#
# Epoch 00044: val_accuracy did not improve from 0.86090
# Epoch 45/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.5084 - accuracy: 0.9006 - val_loss: 0.6788 - val_accuracy: 0.8533
#
# Epoch 00045: val_accuracy did not improve from 0.86090
# Epoch 46/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.4987 - accuracy: 0.9052 - val_loss: 0.8065 - val_accuracy: 0.8237
#
# Epoch 00046: val_accuracy did not improve from 0.86090
# Epoch 47/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 41ms/step - loss: 0.4990 - accuracy: 0.9036 - val_loss: 0.8118 - val_accuracy: 0.8220
#
# Epoch 00047: val_accuracy did not improve from 0.86090
# Epoch 48/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.4998 - accuracy: 0.9051 - val_loss: 0.7412 - val_accuracy: 0.8417
#
# Epoch 00048: val_accuracy did not improve from 0.86090
# Epoch 49/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.4972 - accuracy: 0.9050 - val_loss: 0.7035 - val_accuracy: 0.8427
#
# Epoch 00049: val_accuracy did not improve from 0.86090
# Epoch 50/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.4945 - accuracy: 0.9044 - val_loss: 0.7163 - val_accuracy: 0.8474
#
# Epoch 00050: val_accuracy did not improve from 0.86090
# Epoch 51/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 63s 40ms/step - loss: 0.4926 - accuracy: 0.9066 - val_loss: 0.6252 - val_accuracy: 0.8678
#
# Epoch 00051: val_accuracy improved from 0.86090 to 0.86780, saving model to /content/saved_models/cifar10_%s_model.051.h5
# Epoch 52/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4877 - accuracy: 0.9092 - val_loss: 0.7090 - val_accuracy: 0.8431
#
# Epoch 00052: val_accuracy did not improve from 0.86780
# Epoch 53/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4908 - accuracy: 0.9074 - val_loss: 0.7616 - val_accuracy: 0.8323
#
# Epoch 00053: val_accuracy did not improve from 0.86780
# Epoch 54/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4829 - accuracy: 0.9092 - val_loss: 0.8250 - val_accuracy: 0.8156
#
# Epoch 00054: val_accuracy did not improve from 0.86780
# Epoch 55/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4821 - accuracy: 0.9098 - val_loss: 0.6862 - val_accuracy: 0.8459
#
# Epoch 00055: val_accuracy did not improve from 0.86780
# Epoch 56/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4804 - accuracy: 0.9086 - val_loss: 0.6674 - val_accuracy: 0.8597
#
# Epoch 00056: val_accuracy did not improve from 0.86780
# Epoch 57/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4827 - accuracy: 0.9092 - val_loss: 0.6883 - val_accuracy: 0.8560
#
# Epoch 00057: val_accuracy did not improve from 0.86780
# Epoch 58/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4818 - accuracy: 0.9087 - val_loss: 0.6916 - val_accuracy: 0.8466
#
# Epoch 00058: val_accuracy did not improve from 0.86780
# Epoch 59/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4726 - accuracy: 0.9118 - val_loss: 0.6701 - val_accuracy: 0.8519
#
# Epoch 00059: val_accuracy did not improve from 0.86780
# Epoch 60/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4757 - accuracy: 0.9116 - val_loss: 0.6112 - val_accuracy: 0.8696
#
# Epoch 00060: val_accuracy improved from 0.86780 to 0.86960, saving model to /content/saved_models/cifar10_%s_model.060.h5
# Epoch 61/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.4757 - accuracy: 0.9105 - val_loss: 0.6939 - val_accuracy: 0.8471
#
# Epoch 00061: val_accuracy did not improve from 0.86960
# Epoch 62/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4684 - accuracy: 0.9138 - val_loss: 0.6581 - val_accuracy: 0.8601
#
# Epoch 00062: val_accuracy did not improve from 0.86960
# Epoch 63/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4736 - accuracy: 0.9114 - val_loss: 0.6699 - val_accuracy: 0.8577
#
# Epoch 00063: val_accuracy did not improve from 0.86960
# Epoch 64/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4685 - accuracy: 0.9124 - val_loss: 0.6928 - val_accuracy: 0.8552
#
# Epoch 00064: val_accuracy did not improve from 0.86960
# Epoch 65/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.4677 - accuracy: 0.9131 - val_loss: 0.6735 - val_accuracy: 0.8593
#
# Epoch 00065: val_accuracy did not improve from 0.86960
# Epoch 66/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4642 - accuracy: 0.9147 - val_loss: 0.7506 - val_accuracy: 0.8351
#
# Epoch 00066: val_accuracy did not improve from 0.86960
# Epoch 67/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4641 - accuracy: 0.9140 - val_loss: 0.6594 - val_accuracy: 0.8590
#
# Epoch 00067: val_accuracy did not improve from 0.86960
# Epoch 68/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.4609 - accuracy: 0.9153 - val_loss: 0.7352 - val_accuracy: 0.8423
#
# Epoch 00068: val_accuracy did not improve from 0.86960
# Epoch 69/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4580 - accuracy: 0.9158 - val_loss: 0.6051 - val_accuracy: 0.8781
#
# Epoch 00069: val_accuracy improved from 0.86960 to 0.87810, saving model to /content/saved_models/cifar10_%s_model.069.h5
# Epoch 70/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.4591 - accuracy: 0.9150 - val_loss: 0.5889 - val_accuracy: 0.8788
#
# Epoch 00070: val_accuracy improved from 0.87810 to 0.87880, saving model to /content/saved_models/cifar10_%s_model.070.h5
# Epoch 71/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4618 - accuracy: 0.9157 - val_loss: 0.7100 - val_accuracy: 0.8464
#
# Epoch 00071: val_accuracy did not improve from 0.87880
# Epoch 72/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4584 - accuracy: 0.9168 - val_loss: 0.6079 - val_accuracy: 0.8721
#
# Epoch 00072: val_accuracy did not improve from 0.87880
# Epoch 73/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 40ms/step - loss: 0.4547 - accuracy: 0.9169 - val_loss: 0.6588 - val_accuracy: 0.8540
#
# Epoch 00073: val_accuracy did not improve from 0.87880
# Epoch 74/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.4519 - accuracy: 0.9193 - val_loss: 0.6158 - val_accuracy: 0.8676
#
# Epoch 00074: val_accuracy did not improve from 0.87880
# Epoch 75/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4520 - accuracy: 0.9181 - val_loss: 0.6049 - val_accuracy: 0.8745
#
# Epoch 00075: val_accuracy did not improve from 0.87880
# Epoch 76/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4538 - accuracy: 0.9161 - val_loss: 0.6605 - val_accuracy: 0.8578
#
# Epoch 00076: val_accuracy did not improve from 0.87880
# Epoch 77/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4523 - accuracy: 0.9178 - val_loss: 0.7021 - val_accuracy: 0.8459
#
# Epoch 00077: val_accuracy did not improve from 0.87880
# Epoch 78/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4495 - accuracy: 0.9194 - val_loss: 0.6338 - val_accuracy: 0.8654
#
# Epoch 00078: val_accuracy did not improve from 0.87880
# Epoch 79/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4520 - accuracy: 0.9172 - val_loss: 0.7147 - val_accuracy: 0.8421
#
# Epoch 00079: val_accuracy did not improve from 0.87880
# Epoch 80/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4482 - accuracy: 0.9193 - val_loss: 0.8469 - val_accuracy: 0.8178
#
# Epoch 00080: val_accuracy did not improve from 0.87880
# Epoch 81/200
# Learning rate:  0.001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4461 - accuracy: 0.9188 - val_loss: 0.6349 - val_accuracy: 0.8681
#
# Epoch 00081: val_accuracy did not improve from 0.87880
# Epoch 82/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.3572 - accuracy: 0.9506 - val_loss: 0.4769 - val_accuracy: 0.9121
#
# Epoch 00082: val_accuracy improved from 0.87880 to 0.91210, saving model to /content/saved_models/cifar10_%s_model.082.h5
# Epoch 83/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.3248 - accuracy: 0.9619 - val_loss: 0.4667 - val_accuracy: 0.9143
#
# Epoch 00083: val_accuracy improved from 0.91210 to 0.91430, saving model to /content/saved_models/cifar10_%s_model.083.h5
# Epoch 84/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.3075 - accuracy: 0.9669 - val_loss: 0.4672 - val_accuracy: 0.9142
#
# Epoch 00084: val_accuracy did not improve from 0.91430
# Epoch 85/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2966 - accuracy: 0.9690 - val_loss: 0.4618 - val_accuracy: 0.9175
#
# Epoch 00085: val_accuracy improved from 0.91430 to 0.91750, saving model to /content/saved_models/cifar10_%s_model.085.h5
# Epoch 86/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2842 - accuracy: 0.9722 - val_loss: 0.4626 - val_accuracy: 0.9166
#
# Epoch 00086: val_accuracy did not improve from 0.91750
# Epoch 87/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.2745 - accuracy: 0.9738 - val_loss: 0.4634 - val_accuracy: 0.9145
#
# Epoch 00087: val_accuracy did not improve from 0.91750
# Epoch 88/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2691 - accuracy: 0.9749 - val_loss: 0.4685 - val_accuracy: 0.9140
#
# Epoch 00088: val_accuracy did not improve from 0.91750
# Epoch 89/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2603 - accuracy: 0.9767 - val_loss: 0.4693 - val_accuracy: 0.9109
#
# Epoch 00089: val_accuracy did not improve from 0.91750
# Epoch 90/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2551 - accuracy: 0.9767 - val_loss: 0.4702 - val_accuracy: 0.9135
#
# Epoch 00090: val_accuracy did not improve from 0.91750
# Epoch 91/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2472 - accuracy: 0.9795 - val_loss: 0.4675 - val_accuracy: 0.9137
#
# Epoch 00091: val_accuracy did not improve from 0.91750
# Epoch 92/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2413 - accuracy: 0.9797 - val_loss: 0.4599 - val_accuracy: 0.9142
#
# Epoch 00092: val_accuracy did not improve from 0.91750
# Epoch 93/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2366 - accuracy: 0.9804 - val_loss: 0.4663 - val_accuracy: 0.9142
#
# Epoch 00093: val_accuracy did not improve from 0.91750
# Epoch 94/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2301 - accuracy: 0.9822 - val_loss: 0.4760 - val_accuracy: 0.9132
#
# Epoch 00094: val_accuracy did not improve from 0.91750
# Epoch 95/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2262 - accuracy: 0.9828 - val_loss: 0.4622 - val_accuracy: 0.9168
#
# Epoch 00095: val_accuracy did not improve from 0.91750
# Epoch 96/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2181 - accuracy: 0.9848 - val_loss: 0.4665 - val_accuracy: 0.9178
#
# Epoch 00096: val_accuracy improved from 0.91750 to 0.91780, saving model to /content/saved_models/cifar10_%s_model.096.h5
# Epoch 97/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2185 - accuracy: 0.9840 - val_loss: 0.4701 - val_accuracy: 0.9139
#
# Epoch 00097: val_accuracy did not improve from 0.91780
# Epoch 98/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2139 - accuracy: 0.9841 - val_loss: 0.4679 - val_accuracy: 0.9127
#
# Epoch 00098: val_accuracy did not improve from 0.91780
# Epoch 99/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2105 - accuracy: 0.9850 - val_loss: 0.4738 - val_accuracy: 0.9150
#
# Epoch 00099: val_accuracy did not improve from 0.91780
# Epoch 100/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2077 - accuracy: 0.9850 - val_loss: 0.4673 - val_accuracy: 0.9127
#
# Epoch 00100: val_accuracy did not improve from 0.91780
# Epoch 101/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2016 - accuracy: 0.9868 - val_loss: 0.4746 - val_accuracy: 0.9146
#
# Epoch 00101: val_accuracy did not improve from 0.91780
# Epoch 102/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1987 - accuracy: 0.9870 - val_loss: 0.4688 - val_accuracy: 0.9146
#
# Epoch 00102: val_accuracy did not improve from 0.91780
# Epoch 103/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1982 - accuracy: 0.9864 - val_loss: 0.4747 - val_accuracy: 0.9115
#
# Epoch 00103: val_accuracy did not improve from 0.91780
# Epoch 104/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1942 - accuracy: 0.9870 - val_loss: 0.4792 - val_accuracy: 0.9126
#
# Epoch 00104: val_accuracy did not improve from 0.91780
# Epoch 105/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1895 - accuracy: 0.9885 - val_loss: 0.4767 - val_accuracy: 0.9136
#
# Epoch 00105: val_accuracy did not improve from 0.91780
# Epoch 106/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1873 - accuracy: 0.9882 - val_loss: 0.4824 - val_accuracy: 0.9145
#
# Epoch 00106: val_accuracy did not improve from 0.91780
# Epoch 107/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1868 - accuracy: 0.9875 - val_loss: 0.4816 - val_accuracy: 0.9131
#
# Epoch 00107: val_accuracy did not improve from 0.91780
# Epoch 108/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1824 - accuracy: 0.9888 - val_loss: 0.4818 - val_accuracy: 0.9129
#
# Epoch 00108: val_accuracy did not improve from 0.91780
# Epoch 109/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1820 - accuracy: 0.9888 - val_loss: 0.4862 - val_accuracy: 0.9114
#
# Epoch 00109: val_accuracy did not improve from 0.91780
# Epoch 110/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1798 - accuracy: 0.9888 - val_loss: 0.4799 - val_accuracy: 0.9126
#
# Epoch 00110: val_accuracy did not improve from 0.91780
# Epoch 111/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1778 - accuracy: 0.9891 - val_loss: 0.4801 - val_accuracy: 0.9140
#
# Epoch 00111: val_accuracy did not improve from 0.91780
# Epoch 112/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1736 - accuracy: 0.9902 - val_loss: 0.4872 - val_accuracy: 0.9142
#
# Epoch 00112: val_accuracy did not improve from 0.91780
# Epoch 113/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1734 - accuracy: 0.9886 - val_loss: 0.4925 - val_accuracy: 0.9123
#
# Epoch 00113: val_accuracy did not improve from 0.91780
# Epoch 114/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1698 - accuracy: 0.9903 - val_loss: 0.4886 - val_accuracy: 0.9136
#
# Epoch 00114: val_accuracy did not improve from 0.91780
# Epoch 115/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.1694 - accuracy: 0.9895 - val_loss: 0.4925 - val_accuracy: 0.9137
#
# Epoch 00115: val_accuracy did not improve from 0.91780
# Epoch 116/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1657 - accuracy: 0.9908 - val_loss: 0.4767 - val_accuracy: 0.9164
#
# Epoch 00116: val_accuracy did not improve from 0.91780
# Epoch 117/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1655 - accuracy: 0.9902 - val_loss: 0.4792 - val_accuracy: 0.9139
#
# Epoch 00117: val_accuracy did not improve from 0.91780
# Epoch 118/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1646 - accuracy: 0.9898 - val_loss: 0.4830 - val_accuracy: 0.9126
#
# Epoch 00118: val_accuracy did not improve from 0.91780
# Epoch 119/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1615 - accuracy: 0.9909 - val_loss: 0.4966 - val_accuracy: 0.9122
#
# Epoch 00119: val_accuracy did not improve from 0.91780
# Epoch 120/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1603 - accuracy: 0.9909 - val_loss: 0.4896 - val_accuracy: 0.9118
#
# Epoch 00120: val_accuracy did not improve from 0.91780
# Epoch 121/200
# Learning rate:  0.0001
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1592 - accuracy: 0.9905 - val_loss: 0.4889 - val_accuracy: 0.9107
#
# Epoch 00121: val_accuracy did not improve from 0.91780
# Epoch 122/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1529 - accuracy: 0.9928 - val_loss: 0.4767 - val_accuracy: 0.9158
#
# Epoch 00122: val_accuracy did not improve from 0.91780
# Epoch 123/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1492 - accuracy: 0.9940 - val_loss: 0.4712 - val_accuracy: 0.9170
#
# Epoch 00123: val_accuracy did not improve from 0.91780
# Epoch 124/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1492 - accuracy: 0.9942 - val_loss: 0.4724 - val_accuracy: 0.9163
#
# Epoch 00124: val_accuracy did not improve from 0.91780
# Epoch 125/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1484 - accuracy: 0.9944 - val_loss: 0.4704 - val_accuracy: 0.9165
#
# Epoch 00125: val_accuracy did not improve from 0.91780
# Epoch 126/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1470 - accuracy: 0.9949 - val_loss: 0.4724 - val_accuracy: 0.9170
#
# Epoch 00126: val_accuracy did not improve from 0.91780
# Epoch 127/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1474 - accuracy: 0.9944 - val_loss: 0.4720 - val_accuracy: 0.9169
#
# Epoch 00127: val_accuracy did not improve from 0.91780
# Epoch 128/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1470 - accuracy: 0.9946 - val_loss: 0.4708 - val_accuracy: 0.9169
#
# Epoch 00128: val_accuracy did not improve from 0.91780
# Epoch 129/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1453 - accuracy: 0.9951 - val_loss: 0.4711 - val_accuracy: 0.9174
#
# Epoch 00129: val_accuracy did not improve from 0.91780
# Epoch 130/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1462 - accuracy: 0.9949 - val_loss: 0.4755 - val_accuracy: 0.9162
#
# Epoch 00130: val_accuracy did not improve from 0.91780
# Epoch 131/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1435 - accuracy: 0.9958 - val_loss: 0.4735 - val_accuracy: 0.9174
#
# Epoch 00131: val_accuracy did not improve from 0.91780
# Epoch 132/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1442 - accuracy: 0.9955 - val_loss: 0.4772 - val_accuracy: 0.9156
#
# Epoch 00132: val_accuracy did not improve from 0.91780
# Epoch 133/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1437 - accuracy: 0.9952 - val_loss: 0.4764 - val_accuracy: 0.9158
#
# Epoch 00133: val_accuracy did not improve from 0.91780
# Epoch 134/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1426 - accuracy: 0.9958 - val_loss: 0.4744 - val_accuracy: 0.9168
#
# Epoch 00134: val_accuracy did not improve from 0.91780
# Epoch 135/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1423 - accuracy: 0.9959 - val_loss: 0.4778 - val_accuracy: 0.9162
#
# Epoch 00135: val_accuracy did not improve from 0.91780
# Epoch 136/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1427 - accuracy: 0.9960 - val_loss: 0.4758 - val_accuracy: 0.9168
#
# Epoch 00136: val_accuracy did not improve from 0.91780
# Epoch 137/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1423 - accuracy: 0.9955 - val_loss: 0.4796 - val_accuracy: 0.9166
#
# Epoch 00137: val_accuracy did not improve from 0.91780
# Epoch 138/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1413 - accuracy: 0.9957 - val_loss: 0.4796 - val_accuracy: 0.9180
#
# Epoch 00138: val_accuracy improved from 0.91780 to 0.91800, saving model to /content/saved_models/cifar10_%s_model.138.h5
# Epoch 139/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1405 - accuracy: 0.9964 - val_loss: 0.4789 - val_accuracy: 0.9184
#
# Epoch 00139: val_accuracy improved from 0.91800 to 0.91840, saving model to /content/saved_models/cifar10_%s_model.139.h5
# Epoch 140/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1409 - accuracy: 0.9961 - val_loss: 0.4801 - val_accuracy: 0.9172
#
# Epoch 00140: val_accuracy did not improve from 0.91840
# Epoch 141/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1400 - accuracy: 0.9961 - val_loss: 0.4796 - val_accuracy: 0.9170
#
# Epoch 00141: val_accuracy did not improve from 0.91840
# Epoch 142/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1399 - accuracy: 0.9961 - val_loss: 0.4773 - val_accuracy: 0.9172
#
# Epoch 00142: val_accuracy did not improve from 0.91840
# Epoch 143/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1400 - accuracy: 0.9959 - val_loss: 0.4774 - val_accuracy: 0.9178
#
# Epoch 00143: val_accuracy did not improve from 0.91840
# Epoch 144/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1392 - accuracy: 0.9962 - val_loss: 0.4780 - val_accuracy: 0.9169
#
# Epoch 00144: val_accuracy did not improve from 0.91840
# Epoch 145/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1387 - accuracy: 0.9963 - val_loss: 0.4770 - val_accuracy: 0.9171
#
# Epoch 00145: val_accuracy did not improve from 0.91840
# Epoch 146/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1395 - accuracy: 0.9960 - val_loss: 0.4785 - val_accuracy: 0.9172
#
# Epoch 00146: val_accuracy did not improve from 0.91840
# Epoch 147/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1376 - accuracy: 0.9966 - val_loss: 0.4784 - val_accuracy: 0.9164
#
# Epoch 00147: val_accuracy did not improve from 0.91840
# Epoch 148/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1376 - accuracy: 0.9966 - val_loss: 0.4805 - val_accuracy: 0.9174
#
# Epoch 00148: val_accuracy did not improve from 0.91840
# Epoch 149/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1379 - accuracy: 0.9963 - val_loss: 0.4806 - val_accuracy: 0.9167
#
# Epoch 00149: val_accuracy did not improve from 0.91840
# Epoch 150/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1383 - accuracy: 0.9960 - val_loss: 0.4799 - val_accuracy: 0.9176
#
# Epoch 00150: val_accuracy did not improve from 0.91840
# Epoch 151/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1373 - accuracy: 0.9960 - val_loss: 0.4819 - val_accuracy: 0.9166
#
# Epoch 00151: val_accuracy did not improve from 0.91840
# Epoch 152/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1370 - accuracy: 0.9964 - val_loss: 0.4824 - val_accuracy: 0.9168
#
# Epoch 00152: val_accuracy did not improve from 0.91840
# Epoch 153/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1365 - accuracy: 0.9965 - val_loss: 0.4818 - val_accuracy: 0.9176
#
# Epoch 00153: val_accuracy did not improve from 0.91840
# Epoch 154/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1363 - accuracy: 0.9964 - val_loss: 0.4801 - val_accuracy: 0.9179
#
# Epoch 00154: val_accuracy did not improve from 0.91840
# Epoch 155/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1359 - accuracy: 0.9967 - val_loss: 0.4830 - val_accuracy: 0.9179
#
# Epoch 00155: val_accuracy did not improve from 0.91840
# Epoch 156/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1355 - accuracy: 0.9965 - val_loss: 0.4842 - val_accuracy: 0.9169
#
# Epoch 00156: val_accuracy did not improve from 0.91840
# Epoch 157/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1358 - accuracy: 0.9965 - val_loss: 0.4840 - val_accuracy: 0.9174
#
# Epoch 00157: val_accuracy did not improve from 0.91840
# Epoch 158/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1343 - accuracy: 0.9969 - val_loss: 0.4825 - val_accuracy: 0.9178
#
# Epoch 00158: val_accuracy did not improve from 0.91840
# Epoch 159/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1340 - accuracy: 0.9970 - val_loss: 0.4856 - val_accuracy: 0.9172
#
# Epoch 00159: val_accuracy did not improve from 0.91840
# Epoch 160/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1345 - accuracy: 0.9965 - val_loss: 0.4833 - val_accuracy: 0.9164
#
# Epoch 00160: val_accuracy did not improve from 0.91840
# Epoch 161/200
# Learning rate:  1e-05
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1345 - accuracy: 0.9965 - val_loss: 0.4847 - val_accuracy: 0.9181
#
# Epoch 00161: val_accuracy did not improve from 0.91840
# Epoch 162/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1341 - accuracy: 0.9967 - val_loss: 0.4842 - val_accuracy: 0.9177
#
# Epoch 00162: val_accuracy did not improve from 0.91840
# Epoch 163/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1338 - accuracy: 0.9967 - val_loss: 0.4846 - val_accuracy: 0.9174
#
# Epoch 00163: val_accuracy did not improve from 0.91840
# Epoch 164/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1334 - accuracy: 0.9970 - val_loss: 0.4845 - val_accuracy: 0.9177
#
# Epoch 00164: val_accuracy did not improve from 0.91840
# Epoch 165/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1337 - accuracy: 0.9969 - val_loss: 0.4835 - val_accuracy: 0.9183
#
# Epoch 00165: val_accuracy did not improve from 0.91840
# Epoch 166/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1326 - accuracy: 0.9975 - val_loss: 0.4844 - val_accuracy: 0.9172
#
# Epoch 00166: val_accuracy did not improve from 0.91840
# Epoch 167/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1330 - accuracy: 0.9973 - val_loss: 0.4829 - val_accuracy: 0.9176
#
# Epoch 00167: val_accuracy did not improve from 0.91840
# Epoch 168/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1335 - accuracy: 0.9971 - val_loss: 0.4843 - val_accuracy: 0.9178
#
# Epoch 00168: val_accuracy did not improve from 0.91840
# Epoch 169/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1338 - accuracy: 0.9968 - val_loss: 0.4840 - val_accuracy: 0.9175
#
# Epoch 00169: val_accuracy did not improve from 0.91840
# Epoch 170/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1328 - accuracy: 0.9972 - val_loss: 0.4843 - val_accuracy: 0.9173
#
# Epoch 00170: val_accuracy did not improve from 0.91840
# Epoch 171/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1330 - accuracy: 0.9969 - val_loss: 0.4853 - val_accuracy: 0.9183
#
# Epoch 00171: val_accuracy did not improve from 0.91840
# Epoch 172/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1331 - accuracy: 0.9970 - val_loss: 0.4838 - val_accuracy: 0.9178
#
# Epoch 00172: val_accuracy did not improve from 0.91840
# Epoch 173/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1339 - accuracy: 0.9966 - val_loss: 0.4852 - val_accuracy: 0.9175
#
# Epoch 00173: val_accuracy did not improve from 0.91840
# Epoch 174/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1335 - accuracy: 0.9968 - val_loss: 0.4846 - val_accuracy: 0.9177
#
# Epoch 00174: val_accuracy did not improve from 0.91840
# Epoch 175/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1339 - accuracy: 0.9966 - val_loss: 0.4832 - val_accuracy: 0.9183
#
# Epoch 00175: val_accuracy did not improve from 0.91840
# Epoch 176/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1324 - accuracy: 0.9973 - val_loss: 0.4846 - val_accuracy: 0.9181
#
# Epoch 00176: val_accuracy did not improve from 0.91840
# Epoch 177/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1334 - accuracy: 0.9970 - val_loss: 0.4855 - val_accuracy: 0.9179
#
# Epoch 00177: val_accuracy did not improve from 0.91840
# Epoch 178/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1328 - accuracy: 0.9971 - val_loss: 0.4847 - val_accuracy: 0.9179
#
# Epoch 00178: val_accuracy did not improve from 0.91840
# Epoch 179/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1326 - accuracy: 0.9973 - val_loss: 0.4848 - val_accuracy: 0.9181
#
# Epoch 00179: val_accuracy did not improve from 0.91840
# Epoch 180/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1332 - accuracy: 0.9969 - val_loss: 0.4833 - val_accuracy: 0.9184
#
# Epoch 00180: val_accuracy did not improve from 0.91840
# Epoch 181/200
# Learning rate:  1e-06
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1332 - accuracy: 0.9968 - val_loss: 0.4856 - val_accuracy: 0.9179
#
# Epoch 00181: val_accuracy did not improve from 0.91840
# Epoch 182/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1333 - accuracy: 0.9969 - val_loss: 0.4838 - val_accuracy: 0.9179
#
# Epoch 00182: val_accuracy did not improve from 0.91840
# Epoch 183/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1324 - accuracy: 0.9973 - val_loss: 0.4849 - val_accuracy: 0.9176
#
# Epoch 00183: val_accuracy did not improve from 0.91840
# Epoch 184/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1332 - accuracy: 0.9969 - val_loss: 0.4850 - val_accuracy: 0.9184
#
# Epoch 00184: val_accuracy did not improve from 0.91840
# Epoch 185/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1329 - accuracy: 0.9968 - val_loss: 0.4845 - val_accuracy: 0.9181
#
# Epoch 00185: val_accuracy did not improve from 0.91840
# Epoch 186/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1328 - accuracy: 0.9971 - val_loss: 0.4860 - val_accuracy: 0.9183
#
# Epoch 00186: val_accuracy did not improve from 0.91840
# Epoch 187/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1330 - accuracy: 0.9970 - val_loss: 0.4862 - val_accuracy: 0.9182
#
# Epoch 00187: val_accuracy did not improve from 0.91840
# Epoch 188/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1323 - accuracy: 0.9974 - val_loss: 0.4851 - val_accuracy: 0.9178
#
# Epoch 00188: val_accuracy did not improve from 0.91840
# Epoch 189/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1331 - accuracy: 0.9969 - val_loss: 0.4859 - val_accuracy: 0.9181
#
# Epoch 00189: val_accuracy did not improve from 0.91840
# Epoch 190/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1316 - accuracy: 0.9975 - val_loss: 0.4849 - val_accuracy: 0.9182
#
# Epoch 00190: val_accuracy did not improve from 0.91840
# Epoch 191/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1321 - accuracy: 0.9976 - val_loss: 0.4863 - val_accuracy: 0.9177
#
# Epoch 00191: val_accuracy did not improve from 0.91840
# Epoch 192/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1321 - accuracy: 0.9975 - val_loss: 0.4846 - val_accuracy: 0.9182
#
# Epoch 00192: val_accuracy did not improve from 0.91840
# Epoch 193/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1326 - accuracy: 0.9970 - val_loss: 0.4846 - val_accuracy: 0.9181
#
# Epoch 00193: val_accuracy did not improve from 0.91840
# Epoch 194/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1330 - accuracy: 0.9969 - val_loss: 0.4846 - val_accuracy: 0.9179
#
# Epoch 00194: val_accuracy did not improve from 0.91840
# Epoch 195/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1328 - accuracy: 0.9970 - val_loss: 0.4842 - val_accuracy: 0.9179
#
# Epoch 00195: val_accuracy did not improve from 0.91840
# Epoch 196/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1316 - accuracy: 0.9976 - val_loss: 0.4852 - val_accuracy: 0.9178
#
# Epoch 00196: val_accuracy did not improve from 0.91840
# Epoch 197/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1321 - accuracy: 0.9973 - val_loss: 0.4853 - val_accuracy: 0.9180
#
# Epoch 00197: val_accuracy did not improve from 0.91840
# Epoch 198/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1327 - accuracy: 0.9971 - val_loss: 0.4859 - val_accuracy: 0.9180
#
# Epoch 00198: val_accuracy did not improve from 0.91840
# Epoch 199/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 62s 39ms/step - loss: 0.1323 - accuracy: 0.9974 - val_loss: 0.4844 - val_accuracy: 0.9186
#
# Epoch 00199: val_accuracy improved from 0.91840 to 0.91860, saving model to /content/saved_models/cifar10_%s_model.199.h5
# Epoch 200/200
# Learning rate:  5e-07
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1320 - accuracy: 0.9972 - val_loss: 0.4837 - val_accuracy: 0.9184
#
# Epoch 00200: val_accuracy did not improve from 0.91860

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4837 - accuracy: 0.9184
# Test loss: 0.4836726188659668
# Test accuracy: 0.91839998960495
